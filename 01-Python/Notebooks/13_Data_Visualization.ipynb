# %% [markdown]
# Import all the required libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read all the required files.

# %%
data_customers = pd.read_excel('/content/drive/MyDrive/ChaiCode Full Stack Data Science Cohort/Phase 0 - Python Programming for Data Science/Visualization_25May_11AM/customers.xlsx')
data_purchases = pd.read_excel('/content/drive/MyDrive/ChaiCode Full Stack Data Science Cohort/Phase 0 - Python Programming for Data Science/Visualization_25May_11AM/purchases.xlsx')
data_products = pd.read_excel('/content/drive/MyDrive/ChaiCode Full Stack Data Science Cohort/Phase 0 - Python Programming for Data Science/Visualization_25May_11AM/products.xlsx')

# %%
data_customers.shape
# Out:
# (1000, 13)

# %%
data_customers.isnull().sum()
# Out:
# Unnamed: 0       0
# id               0
# first_name       0
# last_name        0
# email            0
# gender           0
# street_num       0
# street_name      0
# street_suffix    0
# city             0
# state            0
# postcode         0
# full_name        0
# dtype: int64

# %%
data_customers.head(5)
# Out:
#        Unnamed: 0  id first_name   last_name                      email  \
# 0   firstCustomer   1     Romain   Southcott  rsouthcott0@clickbank.net
# 1  secondCustomer   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com
# 2               2   3      Bambi     Westrip     bwestrip2@symantec.com
# 3               3   4     Roarke  Pankettman     rpankettman3@wiley.com
# 4               4   5    Mikaela    Althorpe           malthorpe4@51.la
#
#    gender  street_num street_name street_suffix         city       state  \
# 0    Male           1   Trailsway          Road    San Diego  California
# 1    Male           1   Trailsway          Road      El Paso       Texas
# 2  Female        4057    Arkansas        Circle  San Antonio       Texas
# 3    Male          74        Debs         Point      Memphis   Tennessee
# 4    Male          74         2nd         Drive    Baltimore    Maryland
#
#    postcode          full_name
# 0     92127   Romain Southcott
# 1     78220   Cosimo Molyneaux
# 2     78220      Bambi Westrip
# 3     38150  Roarke Pankettman
# 4     83732   Mikaela Althorpe

# %%
data_customers.drop(columns=['Unnamed: 0'], inplace=True)
data_customers.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male           1
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male           1
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female        4057
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male          74
# 4   5    Mikaela    Althorpe           malthorpe4@51.la    Male          74
#
#   street_name street_suffix         city       state  postcode  \
# 0   Trailsway          Road    San Diego  California     92127
# 1   Trailsway          Road      El Paso       Texas     78220
# 2    Arkansas        Circle  San Antonio       Texas     78220
# 3        Debs         Point      Memphis   Tennessee     38150
# 4         2nd         Drive    Baltimore    Maryland     83732
#
#            full_name
# 0   Romain Southcott
# 1   Cosimo Molyneaux
# 2      Bambi Westrip
# 3  Roarke Pankettman
# 4   Mikaela Althorpe

# %%
data_customers.dtypes
# Out:
# id                int64
# first_name       object
# last_name        object
# email            object
# gender           object
# street_num        int64
# street_name      object
# street_suffix    object
# city             object
# state            object
# postcode          int64
# full_name        object
# dtype: object

# %%
data_purchases.isnull().sum()
# Out:
# Unnamed: 0      0
# id              0
# purch_date      0
# customer_num    0
# product_num     0
# amount          0
# paid            0
# dtype: int64

# %%
data_purchases.drop(columns=['Unnamed: 0'], inplace=True)
data_purchases.head()
# Out:
#    id purch_date  customer_num  product_num  amount    paid
# 0   1 2019-01-03           823           27      12  568.92
# 1   2 2019-01-03           606           28      14  395.36
# 2   3 2019-01-03           955            9      17  510.17
# 3   4 2019-01-03           577           19       3   68.49
# 4   5 2019-01-03           429            8      18  759.42

# %%
data_purchases.dtypes
# Out:
# id                       int64
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                   float64
# dtype: object

# %%
data_products.head()
# Out:
#    Unnamed: 0  id                           product   cost   company
# 0           0   1              Liners - Baking Cups   6.36  Skipfire
# 1           1   2        Nori Sea Weed - Gold Label  85.74   Dynazzy
# 2           2   3                Bar Bran Honey Nut  65.40      Ntag
# 3           3   4        Soup - Campbells Beef Stew  68.16  Photojam
# 4           4   5  Wine - Shiraz Wolf Blass Premium  87.39      Eare

# %%
data_products.drop(columns=['Unnamed: 0'], inplace=True)
data_products.head()
# Out:
#    id                           product   cost   company
# 0   1              Liners - Baking Cups   6.36  Skipfire
# 1   2        Nori Sea Weed - Gold Label  85.74   Dynazzy
# 2   3                Bar Bran Honey Nut  65.40      Ntag
# 3   4        Soup - Campbells Beef Stew  68.16  Photojam
# 4   5  Wine - Shiraz Wolf Blass Premium  87.39      Eare

# %%
data_products.dtypes
# Out:
# id           int64
# product     object
# cost       float64
# company     object
# dtype: object

# %%
data_customers['id'] = data_customers['id'].astype(object)
data_purchases['id'] = data_purchases['id'].astype(object)
data_products['id'] = data_products['id'].astype(object)
data_customers['postcode'] = data_customers['postcode'].astype(object)
data_customers['street_num'] = data_customers['street_num'].astype(object)

# %%
data_customers.dtypes
# Out:
# id               object
# first_name       object
# last_name        object
# email            object
# gender           object
# street_num       object
# street_name      object
# street_suffix    object
# city             object
# state            object
# postcode         object
# full_name        object
# dtype: object

# %%
data_products.head(20)
# Out:
#     id                             product   cost       company
# 0    1                Liners - Baking Cups   6.36      Skipfire
# 1    2          Nori Sea Weed - Gold Label  85.74       Dynazzy
# 2    3                  Bar Bran Honey Nut  65.40          Ntag
# 3    4          Soup - Campbells Beef Stew  68.16      Photojam
# 4    5    Wine - Shiraz Wolf Blass Premium  87.39          Eare
# 5    6  Wine - White, Riesling, Semi - Dry  99.22      Livepath
# 6    7                        Brandy - Bar  13.83          Oloo
# 7    8                      Onions - White  42.19          Oozz
# 8    9         Lettuce - Baby Salad Greens  30.01        Meevee
# 9   10                Sambuca - Ramazzotti  88.99      Livepath
# 10  11                Coffee - Decafenated  21.47        Meezzy
# 11  12             Lamb Leg - Bone - In Nz  42.56     Photofeed
# 12  13                Lettuce - Spring Mix  19.90  Twitterworks
# 13  14              Cookies Oatmeal Raisin  99.40       Dynabox
# 14  15              Cookies Oatmeal Raisin  14.13          Vitz
# 15  16                   Sausage - Chorizo  55.45       Unknown
# 16  17                     Glaze - Apricot  33.78    Browsezoom
# 17  18                           Squid Ink  56.33         Aibox
# 18  19               Loaf Pan - 2 Lb, Foil  22.83   Brainsphere
# 19  20        Bagel - Everything Presliced  87.05        Trunyx

# %% [markdown]
# Average Cost Per Company

# %%
avg_cost_per_company = data_products.groupby('company')['cost'].mean().reset_index()
avg_cost_per_company
# Out:
#          company    cost
# 0          Aibox  56.330
# 1     Babbleopia  63.980
# 2    Brainsphere  22.830
# 3     Browsezoom  41.050
# 4        Cogibox  51.135
# 5       Digitube   8.550
# 6        Dynabox  99.400
# 7        Dynazzy  85.740
# 8           Eare  87.390
# 9          Eazzy  74.280
# 10      Edgeclub  40.690
# 11        Eimbee  98.740
# 12      Fanoodle  68.630
# 13     Flipstorm  37.790
# 14      Fliptune  75.320
# 15         Gevee  62.600
# 16       Innojam  73.700
# 17  Jabbersphere  30.670
# 18      Linkbuzz  95.680
# 19      Livepath  94.105
# 20         Meemm  65.350
# 21        Meevee  30.010
# 22        Meezzy  21.470
# 23          Muxo  92.330
# 24         Mynte  21.980
# 25          Ntag  60.585
# 26          Oloo  13.830
# 27         Oodoo  37.450
# 28          Oozz  42.190
# 29     Photofeed  42.560
# 30      Photojam  68.160
# 31     Photolist  59.230
# 32         Quatz  13.830
# 33         Quinu  41.220
# 34      Realcube  90.480
# 35     Realpoint  61.990
# 36         Skiba  36.670
# 37       Skinder  84.200
# 38      Skipfire   6.360
# 39        Skyble  99.540
# 40  Thoughtstorm  45.770
# 41   Topiclounge  74.060
# 42        Trunyx  87.050
# 43  Twitterworks  19.900
# 44       Unknown  50.540
# 45          Vitz  22.695
# 46       Voonder  82.220
# 47      Wordware  87.510
# 48        Yakijo  73.050
# 49         Zazio  20.530
# 50       Zoombox  16.270

# %%
type(avg_cost_per_company)
# Out:
# pandas.core.frame.DataFrame

# %%
avg_cost_per_company_v1 = data_products.groupby('company').agg({'cost': 'mean'})
avg_cost_per_company_v1
# Out:
#                 cost
# company
# Aibox         56.330
# Babbleopia    63.980
# Brainsphere   22.830
# Browsezoom    41.050
# Cogibox       51.135
# Digitube       8.550
# Dynabox       99.400
# Dynazzy       85.740
# Eare          87.390
# Eazzy         74.280
# Edgeclub      40.690
# Eimbee        98.740
# Fanoodle      68.630
# Flipstorm     37.790
# Fliptune      75.320
# Gevee         62.600
# Innojam       73.700
# Jabbersphere  30.670
# Linkbuzz      95.680
# Livepath      94.105
# Meemm         65.350
# Meevee        30.010
# Meezzy        21.470
# Muxo          92.330
# Mynte         21.980
# Ntag          60.585
# Oloo          13.830
# Oodoo         37.450
# Oozz          42.190
# Photofeed     42.560
# Photojam      68.160
# Photolist     59.230
# Quatz         13.830
# Quinu         41.220
# Realcube      90.480
# Realpoint     61.990
# Skiba         36.670
# Skinder       84.200
# Skipfire       6.360
# Skyble        99.540
# Thoughtstorm  45.770
# Topiclounge   74.060
# Trunyx        87.050
# Twitterworks  19.900
# Unknown       50.540
# Vitz          22.695
# Voonder       82.220
# Wordware      87.510
# Yakijo        73.050
# Zazio         20.530
# Zoombox       16.270

# %%
type(avg_cost_per_company_v1)
# Out:
# pandas.core.frame.DataFrame

# %%
avg_cost_per_company_v1.head()
# Out:
#                cost
# company
# Aibox        56.330
# Babbleopia   63.980
# Brainsphere  22.830
# Browsezoom   41.050
# Cogibox      51.135

# %%
avg_cost_per_company['company']
# Out:
# 0            Aibox
# 1       Babbleopia
# 2      Brainsphere
# 3       Browsezoom
# 4          Cogibox
# 5         Digitube
# 6          Dynabox
# 7          Dynazzy
# 8             Eare
# 9            Eazzy
# 10        Edgeclub
# 11          Eimbee
# 12        Fanoodle
# 13       Flipstorm
# 14        Fliptune
# 15           Gevee
# 16         Innojam
# 17    Jabbersphere
# 18        Linkbuzz
# 19        Livepath
# 20           Meemm
# 21          Meevee
# 22          Meezzy
# 23            Muxo
# 24           Mynte
# 25            Ntag
# 26            Oloo
# 27           Oodoo
# 28            Oozz
# 29       Photofeed
# 30        Photojam
# 31       Photolist
# 32           Quatz
# 33           Quinu
# 34        Realcube
# 35       Realpoint
# 36           Skiba
# 37         Skinder
# 38        Skipfire
# 39          Skyble
# 40    Thoughtstorm
# 41     Topiclounge
# 42          Trunyx
# 43    Twitterworks
# 44         Unknown
# 45            Vitz
# 46         Voonder
# 47        Wordware
# 48          Yakijo
# 49           Zazio
# 50         Zoombox
# Name: company, dtype: object

# %%
avg_cost_per_company['company']
# Out:
# 0            Aibox
# 1       Babbleopia
# 2      Brainsphere
# 3       Browsezoom
# 4          Cogibox
# 5         Digitube
# 6          Dynabox
# 7          Dynazzy
# 8             Eare
# 9            Eazzy
# 10        Edgeclub
# 11          Eimbee
# 12        Fanoodle
# 13       Flipstorm
# 14        Fliptune
# 15           Gevee
# 16         Innojam
# 17    Jabbersphere
# 18        Linkbuzz
# 19        Livepath
# 20           Meemm
# 21          Meevee
# 22          Meezzy
# 23            Muxo
# 24           Mynte
# 25            Ntag
# 26            Oloo
# 27           Oodoo
# 28            Oozz
# 29       Photofeed
# 30        Photojam
# 31       Photolist
# 32           Quatz
# 33           Quinu
# 34        Realcube
# 35       Realpoint
# 36           Skiba
# 37         Skinder
# 38        Skipfire
# 39          Skyble
# 40    Thoughtstorm
# 41     Topiclounge
# 42          Trunyx
# 43    Twitterworks
# 44         Unknown
# 45            Vitz
# 46         Voonder
# 47        Wordware
# 48          Yakijo
# 49           Zazio
# 50         Zoombox
# Name: company, dtype: object

# %% [markdown]
# Create a bar plot where in x-axis we have company and in y-axis we have average cost per company

# %%
plt.figure(figsize=(18, 12))
plt.bar(avg_cost_per_company['company'], avg_cost_per_company['cost'], color='green')
plt.title('Average product cost per company', fontsize=16)
plt.xlabel('Company', fontsize=12)
plt.ylabel('Average Cost', fontsize=12)

plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', linewidth=0.9)
plt.savefig('average_product_cost_per_company.png')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.boxplot(data_products['cost'])

plt.title("Box Plot of cost of the product", fontsize=16)
plt.ylabel('Cost of the product')
plt.savefig('boxplot_cost_product.png')
plt.show()

# %% [markdown]
# Create a box plot of the "paid" column in the data_purchases dataframe.

# %%
plt.figure(figsize=(8,6))
plt.boxplot(data_purchases['paid'])

plt.title("Box Plot for amt paid for purchases", fontsize=16)
plt.ylabel('Amt paid')
plt.savefig('boxplot_purchases_paid.png')
plt.show()

# %% [markdown]
# Gender Distribution: Pie Chart

# %%
gender_counts = data_customers['gender'].value_counts()
gender_counts
# Out:
# gender
# Male      528
# Female    472
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,4))
plt.pie(gender_counts, autopct='%1.1f%%' ,labels=gender_counts.index)
plt.title('Gender Distribution of customers')
plt.savefig('gender_distribution.png')
plt.show()

# %% [markdown]
# Task 1: Visualize the customer spending patterns over time on a monthly basis using a line plot.

# %%
data_purchases.head()

## data_purchases['purch_date'] => Month --> x-axis
## data_purchases['amount'] => Month wise amount --> y-axis
## finally, create the line plot (plt.plot(x, y))
# Out:
#   id purch_date  customer_num  product_num  amount    paid
# 0  1 2019-01-03           823           27      12  568.92
# 1  2 2019-01-03           606           28      14  395.36
# 2  3 2019-01-03           955            9      17  510.17
# 3  4 2019-01-03           577           19       3   68.49
# 4  5 2019-01-03           429            8      18  759.42

# %% [markdown]
# Seaborn: simply built on top of matplotlib only.

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Total tips per day

# %%
sns.barplot(x='day', y='tip', data=tips, estimator=sum)
plt.title('Total Tips by day')
plt.xlabel('Day')
plt.ylabel('Total tips')
plt.savefig('tips_per_day.png')
plt.show()

# %% [markdown]
# KDE Plots: Visualize the probability density function of any given variable.

# %%
sns.kdeplot(data=tips, x='total_bill', hue='time', fill=True)
plt.title('KDE Plot of the total bill')
plt.xlabel('Total Bill')
plt.show()

# %% [markdown]
# BoxPlot

# %%
sns.boxplot(x='day', y='tip', data=tips)
plt.title('Distribution of tips per day')
plt.xlabel('Day')
plt.ylabel('Tips')
plt.show()

# %% [markdown]
# Task 2: Explore about the violinplot (detect the outliers just like the boxplot)

# %%
sns.pairplot(data=tips)

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.catplot(x='smoker', y='tip', data=tips)

# %% [markdown]
# Correlation Coefficient

# %%
numeric_tips = tips.select_dtypes(include='number')
correlation_coefficient = numeric_tips.corr()
print(correlation_coefficient)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(correlation_coefficient, annot=True)
plt.title('Correlation Coefficient Matrix')
plt.savefig('correlation_coefficient.png')
plt.show()

# %%
data_customers.to_csv('customers.csv')
data_products.to_csv('products.csv')
data_purchases.to_csv('purchases.csv')
