# %%
file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
content = file.read()
print(content)
# Out:
# My name is Priya Bhatia
# I am currently working as a Lead Data Scientist at Turing, also teach learners about the concepts of data science.

# %%
file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
print(file.read(6))
# Out:
# My nam

# %%
file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
print(file.readline())
# Out:
# My name is Priya Bhatia

# %%
print(file.readline())
# Out:
# I am currently working as a Lead Data Scientist at Turing, also teach learners about the concepts of data science.

# %%
file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
print(file.readlines())
# Out:
# ['My name is Priya Bhatia\n', 'I am currently working as a \x93Lead Data Scientist\x94 at Turing, also teach learners about the concepts of data science.\n']

# %%
file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
for line in file.readlines():
  print(line)
# Out:
# My name is Priya Bhatia
#
# I am currently working as a Lead Data Scientist at Turing, also teach learners about the concepts of data science.

# %%
file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
## operations on file
file.close()

# %%
## My_textual_file.txt
try:
  file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
except FileNotFoundError:
  print("Error: File not found")
else:
  content = file.read()
  print(content)
finally:
  file.close()
# Out:
# My name is Priya Bhatia
# I am currently working as a Lead Data Scientist at Turing, also teach learners about the concepts of data science.

# %% [markdown]
# write() method returns the number of characters written to the file. It usually overwrites in the original file.

# %%
try:
  file = open('/content/My_Textual_document.txt', 'w', encoding='ISO-8859-1')
except FileNotFoundError:
  print("Error: File not found")
else:
  content = file.write("I have a youtube channel named Priya Bhatia")
  print(content)
finally:
  file.close()
# Out:
# 43

# %%
try:
  file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
except FileNotFoundError:
  print("Error: File not found")
else:
  content = file.read()
  print(content)
finally:
  file.close()
# Out:
# I have a youtube channel named Priya Bhatia

# %%
try:
  file = open('/content/My_Textual_text.txt', 'a', encoding='ISO-8859-1')
except FileNotFoundError:
  print("Error: File not found")
else:
  content = file.write("Hey, My name is Priya")
  print(content)
finally:
  file.close()
# Out:
# 21

# %%
try:
  file = open('/content/My_Textual_document.txt', 'r', encoding='ISO-8859-1')
except FileNotFoundError:
  print("Error: File not found")
else:
  content = file.read()
  print(content)
finally:
  file.close()
# Out:
# I have a youtube channel named Priya BhatiaHey, My name is Priya

# %%
try:
  file = open('/content/My_Textual_text.txt', 'r', encoding='ISO-8859-1')
except FileNotFoundError:
  print("Error: File not found")
else:
  content = file.read()
  print(content)
finally:
  file.close()
# Out:
# Hey, My name is Priya

# %% [markdown]
# Create a new file: Exclusive Creation Mode

# %%
try:
  file = open('/content/myfile.txt', 'x')
  file.write("Hey, How are you? I am doing good and have enrolled into full stack data science course.\n")
  file.write("What are you doing nowadays?\n")
except FileExistsError:
  print("Error: The file 'myfile.txt' already exists")
except Exception:
  print("An unexpected error occured")
# Out:
# Error: The file 'myfile.txt' already exists

# %%
try:
  file = open('/content/myfile.txt', 'r', encoding='ISO-8859-1')
except FileNotFoundError:
  print("Error: File not found")
else:
  content = file.read()
  print(content)
finally:
  file.close()
# Out:
# Hey, How are you? I am doing good and have enrolled into full stack data science course.
# What are you doing nowadays?

# %% [markdown]
# Delete a file

# %%
import os
file_path = '/content/myfile.txt'

try:
  ## critical code to delete the file
  os.remove(file_path)
  print(f"File '{file_path}' deleted successfully")
except FileNotFoundError:
  print(f"File '{file_path}' not found.")
except PermissionError:
  print(f"You don't have a permission to delete '{file_path}'.")
except Exception:
  print("An unexpected error occured")
# Out:
# File '/content/myfile.txt' not found.
